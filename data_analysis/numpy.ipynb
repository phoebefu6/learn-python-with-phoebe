# %%
from data_analysis.tools import add_function
# %run tools.py

# %%
print(url)
# Out:
# https://www.luffycity.com/

# %%
print(add_function(10,12))
# Out:
# 22
# None

# %%
from data_analysis.tools import say_hello

say_hello("Phoebe")
# Out:
# Phoebe say hello to luffy

# %%
add_function(8, 9)
# Out:
# 17

# %%
url
# Out:
# 'https://www.luffycity.com/'

# %% [markdown]
# # Header 1

# %% [markdown]
# ## Header 2

# %% [markdown]
# ### Header 3

# %% [markdown]
# > test test

# %% [markdown]
# * test
# * 1
# * 2
# * 3
# *

# %% [markdown]
# 1. a
# 2. n
# 3. g
# 4. d
# 5. l
# 6. d

# %%
import numpy as np

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
len("dhhkkelglld")
# Out:
# 11

# %%
say_hello('dancer')
# Out:
# dancer say hello to luffy

# %%
# %time
# Out:
# CPU times: user 2 μs, sys: 1e+03 ns, total: 3 μs
# Wall time: 5.72 μs

# %%
def add(number):
    res = 0
    for i in range(number):
        res = res + i
    return res

# %%
add(10)
# Out:
# 45

# %%
add(100)
# Out:
# 4950

# %%
# %time add(1000000)
# Out:
# CPU times: user 25.2 ms, sys: 2.67 ms, total: 27.8 ms
# Wall time: 33.1 ms
# 499999500000

# %%
# %%time
add(1000000)
add(1000000)
add(1000000)
add(1000000)
add(1000000)
add(1000000)
add(1000000)
# Out:
# CPU times: user 130 ms, sys: 3.74 ms, total: 134 ms
# Wall time: 144 ms
# 499999500000
